# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df.columns
# Out:
# Index(['Title', 'Job links', 'Buyer Name', 'Location', 'Price', 'Job Type',
#        'Total Earnings', 'Success Score', 'Badge', 'uplineclampv2',
#        'upskillskip', 'upskillbadge', 'upskillbadge1', 'upskillbadge2',
#        'upskillbadge3', 'upskillbadge4', 'upskillbadge5', 'upskillbadge6',
#        'upskillbadge7', 'upskillbadge8', 'upskillbadge9', 'upskillbadge10',
#        'upskillbadge11', 'upskillbadge12', 'upskillbadge13', 'upskillbadge14',
#        'upskillbadge15'],
#       dtype='object')

# %%
df.head()
# Out:
#                                                Title  \
# 0  \n          Data, Automation, and Analytics Ex...
# 1               \n          Data Scientist\n
# 2  \n          Physicist and Data Scientist with ...
# 3  \n          Data Scientist with R and Python E...
# 4  \n          Data Scientist | 10+ Years Analyti...
#
#                                            Job links  \
# 0  https://www.upwork.com/profile-portraits/c1Z0J...
# 1  https://www.upwork.com/profile-portraits/c1Sdc...
# 2  https://www.upwork.com/profile-portraits/c1jyV...
# 3  https://www.upwork.com/profile-portraits/c1Z0g...
# 4  https://www.upwork.com/profile-portraits/c1qFR...
#
#                             Buyer Name        Location    Price Job Type  \
# 0      \n          Ismail T.\n           United States  $350.00      /hr
# 1  \n          Anastasios S.\n                  Greece   $40.00      /hr
# 2     \n          Dominik G.\n          United Kingdom   $30.00      /hr
# ...

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

df=pd.read_csv(r"E:\flask\data science - Upwork dataset.csv")
df.rename(columns={'upskillbadge':'Job Type1','upskillbadge1':'Job Type2','upskillbadge2':'Job Type3' ,'upskillbadge4':'Job Type4'       ,'Job': 'Job Title','Image':'Job links','Name':'Buyer Name','dinlineblock':'Location','gridcol1':'Job Type5','uppoppertrigger__pcontains_class_mb0':'Total Earnings','upjobsuccesstext':'Success Score','Status':'Badge','uplineclampv2':'Seller Info','upskillbadge3':'Job Type6','upskillbadger4':'Job Type7','upskillbadge5':'Job Type8','upskillbadge6':'Job Type9','upskillbadge7':'Job Type10','upskillbadge8':'Job Type11','upskillbadge8':'Job Type12','upskillbadge9':'Job Type13','upskillbadge10':'Job Type14','upskillbadge11':'Job Type15','upskillbadge12':'Job Type16','upskillbadge13':'Job Type17','upskillbadge14':'Job Type18','upskillbadge15':'Job Type19'},inplace=True)

# %%
df.drop('upskillskip',axis=1,inplace=True)

# %%
df.columns
# Out:
# Index(['Title', 'Job links', 'Buyer Name', 'Location', 'Price', 'Job Type5',
#        'Total Earnings', 'Success Score', 'Badge', 'Seller Info', 'Job Type1',
#        'Job Type2', 'Job Type3', 'Job Type6', 'Job Type4', 'Job Type8',
#        'Job Type9', 'Job Type10', 'Job Type12', 'Job Type13', 'Job Type14',
#        'Job Type15', 'Job Type16', 'Job Type17', 'Job Type18', 'Job Type19'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3709 entries, 0 to 3708
# Data columns (total 26 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Title           3709 non-null   object
#  1   Job links       3697 non-null   object
#  2   Buyer Name      3696 non-null   object
#  3   Location        3695 non-null   object
#  4   Price           3695 non-null   object
#  5   Job Type5       3695 non-null   object
#  6   Total Earnings  3239 non-null   object
#  7   Success Score   2412 non-null   object
#  8   Badge           1610 non-null   object
#  9   Seller Info     3695 non-null   object
#  10  Job Type1       3693 non-null   object
#  11  Job Type2       3684 non-null   object
#  12  Job Type3       3672 non-null   object
#  13  Job Type6       3656 non-null   object
#  14  Job Type4       3613 non-null   object
#  15  Job Type8       3557 non-null   object
#  16  Job Type9       3482 non-null   object
# ...

# %%
df.head()
# Out:
#                                                Title  \
# 0  \n          Data, Automation, and Analytics Ex...
# 1               \n          Data Scientist\n
# 2  \n          Physicist and Data Scientist with ...
# 3  \n          Data Scientist with R and Python E...
# 4  \n          Data Scientist | 10+ Years Analyti...
#
#                                            Job links  \
# 0  https://www.upwork.com/profile-portraits/c1Z0J...
# 1  https://www.upwork.com/profile-portraits/c1Sdc...
# 2  https://www.upwork.com/profile-portraits/c1jyV...
# 3  https://www.upwork.com/profile-portraits/c1Z0g...
# 4  https://www.upwork.com/profile-portraits/c1qFR...
#
#                             Buyer Name        Location    Price Job Type5  \
# 0      \n          Ismail T.\n           United States  $350.00       /hr
# 1  \n          Anastasios S.\n                  Greece   $40.00       /hr
# 2     \n          Dominik G.\n          United Kingdom   $30.00       /hr
# ...

# %%
df = df.replace(r'\\n|\n', '', regex=True)

df.head(5)
# Out:
#                                                Title  \
# 0            Data, Automation, and Analytics Expe...
# 1                             Data Scientist
# 2            Physicist and Data Scientist with a ...
# 3            Data Scientist with R and Python Exp...
# 4            Data Scientist | 10+ Years Analytics...
#
#                                            Job links  \
# 0  https://www.upwork.com/profile-portraits/c1Z0J...
# 1  https://www.upwork.com/profile-portraits/c1Sdc...
# 2  https://www.upwork.com/profile-portraits/c1jyV...
# 3  https://www.upwork.com/profile-portraits/c1Z0g...
# 4  https://www.upwork.com/profile-portraits/c1qFR...
#
#                         Buyer Name        Location    Price Job Type5  \
# 0                Ismail T.           United States  $350.00       /hr
# 1            Anastasios S.                  Greece   $40.00       /hr
# 2               Dominik G.          United Kingdom   $30.00       /hr
# ...

# %%
df[df['Location'] == 'India'].shape[0]
# Out:
# 404

# %%
df[df['Job Type9']=='Deep Learning'].shape[0]
# Out:
# 46

# %%
print(df['Job Type9'].unique())
# Out:
# ['Data Extraction' 'Python' 'Data Analysis' 'Microsoft Power BI' 'PySpark'
#  'Data Analytics' 'Statistics' 'SQL' 'Data Management'
#  'Genomic Data Analysis' 'Microsoft Power BI Data Visualization'
#  'Database' 'Deep Learning' 'Selenium' 'Machine Learning'
#  'Data Analysis Expressions' 'Data Cleansing' 'Biology' 'Tableau' 'Docker'
#  'Supermetrics' 'BigQuery' 'Data Entry' 'Google Data Studio'
#  'Data Science Consultation' 'Plotly' 'scikit-learn' 'Neural Network'
#  'Web Scraper' 'Data Mining' 'Data Collection' 'Data Modeling' 'RStudio'
#  'Data Scraping' 'OpenCV' 'Microsoft Excel' 'Data Labeling' 'MySQL'
#  'Data Processing' 'Interactive Data Visualization' 'Virtual Assistant'
#  'Analytics' 'Data Logistics' 'Microsoft SQL Server Administration'
#  'DataTables' 'Business Intelligence' 'Data Annotation' 'Market Analysis'
#  'IPython' 'Mathematics' 'MATLAB Script' 'Computer Vision' 'Presentations'
#  'ETL' 'ETL Pipeline' 'Business Management' 'Symfony 4' 'MATLAB' 'Stata'
# ...

# %%
df[df['Badge']=='TOP RATED'].shape[0]
# Out:
# 1414
